# %%
import pyautogui
import time
import os


pyautogui.press("win")
time.sleep(2)
pyautogui.write('C:\\Users\\italo.caraujo\\Documents\\test-page\\index.html', interval=0.1)
time.sleep(1)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('Relembrando Fodas', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('Leno Brega', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('197', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('Song by Leno Brega ‧ 2022', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(1)

pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('Orgia de Traveco', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('U.D.R. 666', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("down")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('131', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(1)
pyautogui.write('Seringas Compartilhadas Vol. 2 – Concertos Para Fagote Solo, Em Si Bemol', interval=0.1)
time.sleep(0.5)
pyautogui.press("tab")
time.sleep(0.5)
pyautogui.press("enter")
time.sleep(0.5)
pyautogui.press("enter")
